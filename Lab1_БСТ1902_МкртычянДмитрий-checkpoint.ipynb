# %% [markdown]
# # Лабораторная Работа 1
# ## Выполнил студент группы БСТ1902 Мкртычян Дмитрий Геннадьевич
# ### Задание №1
# Привет мир

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных многомерных матриц

# %%
m = input("Введите ширину матрицы: ")
n = input("Введите высоту матрицы: ")
min_limit = input("Введите минимально возможно значение элемента матрицы: ")
max_limit = input("Введите максимально возможное значение элемента матрицы: ")
matrix = [[0] * n for i in range(m)]
for i in range(n):
    for j in range(m):
        matrix [i][j] = random.randint(min_limit, max_limit)
# Out:
# Введите ширину матрицы: 12
# Введите высоту матрицы: 13
# Введите минимально возможно значение элемента матрицы: 1
# Введите максимально возможное значение элемента матрицы: 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4f7ce5d11f5d> in <module>
#       3 min_limit = input("Введите минимально возможно значение элемента матрицы: ")
#       4 max_limit = input("Введите максимально возможное значение элемента матрицы: ")
# ----> 5 matrix = [[0] * n for i in range(m)]
#       6 for i in range(n):
#       7     for j in range(m):
#
# TypeError: 'str' object cannot be interpreted as an integer
