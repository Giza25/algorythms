# %% [markdown]
# # Лабораторная Работа 1
# ## Выполнил студент группы БСТ1902 Мкртычян Дмитрий Геннадьевич
# ### Задание №1
# Привет мир

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных многомерных матриц

# %%
import random
import math
import sys
import time

# %%
try:
    m = int(input("Введите ширину матрицы: "))
except ValueError:
    m = 50
try:
    n = int(input("Введите высоту матрицы: "))
except ValueError:
    n = 50
try:
    min_limit = int(input("Введите минимально возможно значение элемента матрицы: "))
except ValueError:
    min_limit = -250
try:
    max_limit = int(input("Введите максимально возможное значение элемента матрицы: "))
except ValueError:
    max_limit = 1011

matrix = [[0] * m for i in range(n)]
for i in range(n):
    for j in range(m):
        matrix [i][j] = random.randint(min_limit, max_limit)
        print(matrix[i][j], end = ' ')
    print()
# Out:
# Введите ширину матрицы: 4
# Введите высоту матрицы: 4
# Введите минимально возможно значение элемента матрицы: -50
# Введите максимально возможное значение элемента матрицы: 50
# -22 -27 11 27
# 32 -23 -33 -3
# -30 -49 25 23
# -47 -16 1 47

# %% [markdown]
# ### Задание №3
# Реализовать метоты сортировок массивов: выбором, вставкой, обменом, Шелла, турнирную, быструю и пирамидальную

# %%
# Генерация массива
N = 15
array = [0] * N

def ArrayGenerator(arr):
    for i in range (len(arr)):
        array[i] = random.randint(0, 100)

# %% [markdown]
# #### Сортировка выбором:

# %%
def SelectionSort(arr):
    for i in range(len(arr)): 
        index = i 
        for j in range(i+1, len(arr)): 
            if arr[index] > arr[j]: 
                index = j         
        arr[i], arr[index] = arr[index], arr[i]

# %%
ArrayGenerator(array)
print(array)
startTime = time.perf_counter()
SelectionSort(array)
print(array)
print(time.perf_counter() - startTime)
# Out:
# [32, 61, 97, 49, 87, 62, 2, 41, 7, 69, 3, 95, 45, 52, 11]
# [2, 3, 7, 11, 32, 41, 45, 49, 52, 61, 62, 69, 87, 95, 97]
# 0.0002560999999978719

# %% [markdown]
# #### Сортировка вставкой:

# %%
def InsertSort(arr):
    for i in range (1, len(arr)):
        j = i - 1
        buf = arr[i]
        while j >= 0 and arr[j] > buf:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = buf

# %%
ArrayGenerator(array)
print(array)
startTime = time.perf_counter()
InsertSort(array)
print(array)
print(time.perf_counter() - startTime)
# Out:
# [15, 22, 64, 10, 28, 87, 84, 57, 27, 83, 20, 4, 100, 36, 61]
# [4, 10, 15, 20, 22, 27, 28, 36, 57, 61, 64, 83, 84, 87, 100]
# 0.0002212999999997578

# %% [markdown]
# #### Сортировка обменом:

# %%
def BubbleSort(arr):
    for i in range(len(arr)):
        for j in range(0, len(arr)-i-1): 
            if arr[j] > arr[j+1] : 
                arr[j], arr[j+1] = arr[j+1], arr[j]

# %%
ArrayGenerator(array)
print(array)
startTime = time.perf_counter()
BubbleSort(array)
print(array)
print(time.perf_counter() - startTime)
# Out:
# [91, 30, 4, 15, 49, 10, 6, 72, 33, 37, 81, 14, 95, 39, 57]
# [4, 6, 10, 14, 15, 30, 33, 37, 39, 49, 57, 72, 81, 91, 95]
# 0.00018400000000440286

# %% [markdown]
# #### Сортировка Шелла

# %%
def ShellSort(arr):
    last_index = len(arr) - 1
    power = math.floor(math.log(len(arr) + 1, 2)) # Данный метод выбора шага дает скорость алгоритма О(N^(3/2))
    step = pow(2, power) - 1
    while step > 0:
        for i in range(step, last_index + 1, 1):
            j = i
            delta = j - step
            while delta >= 0 and arr[delta] > arr[j]:
                arr[delta], arr[j] = arr[j], arr[delta]
                j = delta
                delta = j - step
        power -= 1
        step = pow(2, power) - 1

# %%
ArrayGenerator(array)
print(array)
startTime = time.perf_counter()
ShellSort(array)
print(array)
print(time.perf_counter() - startTime)
# Out:
# [0, 13, 23, 91, 53, 47, 15, 33, 94, 34, 81, 9, 50, 63, 10]
# [0, 9, 10, 13, 15, 23, 33, 34, 47, 50, 53, 63, 81, 91, 94]
# 0.00019890000000089003

# %% [markdown]
# #### Быстрая сортировка

# %%
def QuickSort(arr, first = 0, last = None):
    if last == None:
        last = len(arr) - 1
        
    if first >= last:
        return
 
    i, j = first, last
    pivot = arr[(last + first) // 2]
 
    while i <= j:
        while arr[i] < pivot: i += 1
        while arr[j] > pivot: j -= 1
        if i <= j:
            arr[i], arr[j] = arr[j], arr[i]
            i, j = i + 1, j - 1
            
    QuickSort(arr, first, j)
    QuickSort(arr, i, last)

# %%
ArrayGenerator(array)
print(array)
startTime = time.perf_counter()
QuickSort(array)
print(array)
print(time.perf_counter() - startTime)
# Out:
# [89, 61, 3, 43, 93, 79, 51, 53, 22, 97, 11, 30, 73, 10, 38]
# [3, 10, 11, 22, 30, 38, 43, 51, 53, 61, 73, 79, 89, 93, 97]
# 0.000248200000001475

# %% [markdown]
# #### Турнирная сортировка

# %%
def TournamentSort(arr):
    tree = [None] * 2 * (len(arr) + len(arr) % 2)
    index = len(tree) - len(arr) - len(arr) % 2
    
    for i, v in enumerate(arr):
        tree[index + i] = (i, v)
    
    for j in range(len(arr)):
        n = len(arr)
        index = len(tree) - len(arr) - len(arr) % 2
        while index > -1:
            n = (n + 1) // 2
            for i in range(n):
                i = max(index + i * 2, 1)
                if tree[i] != None and tree[i + 1] != None:
                    if tree[i][1] < tree[i + 1][1]:
                        tree[i // 2] = tree[i]
                    else:
                        tree[i // 2] = tree[i + 1]
                else:
                    tree[i // 2] = tree[i] if tree[i] != None else tree[i + 1]
            index -= n

        index, x = tree[0]
        arr[j] = x
        tree[len(tree) - len(arr) - len(arr) % 2 + index] = None

# %%
ArrayGenerator(array)
print(array)
startTime = time.perf_counter()
TournamentSort(array)
print(array)
print(time.perf_counter() - startTime)
# Out:
# [66, 60, 34, 88, 80, 71, 32, 62, 35, 8, 59, 64, 100, 51, 69]
# [8, 32, 34, 35, 51, 59, 60, 62, 64, 66, 69, 71, 80, 88, 100]
# 0.0005369999999942365

# %% [markdown]
# #### Пирамидальная сортировка

# %%
def Heapify(arr, n, i):
    largest = i
    l = 2 * i + 1
    r = 2 * i + 2
    if l < n and arr[i] < arr[l]:
        largest = l
    if r < n and arr[largest] < arr[r]:
        largest = r
    if largest != i:
        arr[i],arr[largest] = arr[largest],arr[i] 
        Heapify(arr, n, largest)

def HeapSort(arr):
    n = len(arr)
    for i in range(n, -1, -1):
        Heapify(arr, len(arr), i)
    for i in range(n-1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]
        Heapify(arr, i, 0)

# %%
ArrayGenerator(array)
print(array)
startTime = time.perf_counter()
HeapSort(array)
print(array)
print(time.perf_counter() - startTime)
# Out:
# [80, 41, 15, 59, 18, 11, 79, 66, 22, 96, 20, 100, 30, 6, 60]
# [6, 11, 15, 18, 20, 22, 30, 41, 59, 60, 66, 79, 80, 96, 100]
# 0.0001905000000022028

# %% [markdown]
# #### Встроенная сортировка

# %%
ArrayGenerator(array)
print(array)
startTime = time.perf_counter()
print(sorted(array))
print(time.perf_counter() - startTime)
# Out:
# [58, 94, 8, 93, 88, 43, 24, 23, 57, 12, 80, 35, 56, 49, 24]
# [8, 12, 23, 24, 24, 35, 43, 49, 56, 57, 58, 80, 88, 93, 94]
# 0.0001887000000024841
